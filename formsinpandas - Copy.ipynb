# %%
#Load and Display the Dataset
import pandas as pd
df = pd.read_csv('pandas_forms_data.csv')
df.head()
# Out:
#    Employee_ID           Name  Age Department  Salary Joining_Date  \
# 0          101       John Doe   28         IT   50000   2018-06-15
# 1          102     Jane Smith   32         HR   60000   2016-09-23
# 2          103    Emily Davis   45    Finance   80000   2012-11-04
# 3          104  Michael Brown   29         IT   55000   2019-07-12
# 4          105   Chris Wilson   35  Marketing   62000   2015-03-19
#
#             City
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3       New York
# 4  San Francisco

# %%
#Convert a Column to a Series
import pandas as pd
df = pd.read_csv("pandas_forms_data.csv")
pandas_series=df["Name"]
print(pandas_series)
# Out:
# 0         John Doe
# 1       Jane Smith
# 2      Emily Davis
# 3    Michael Brown
# 4     Chris Wilson
# 5    Sarah Johnson
# 6        David Lee
# 7     Robert White
# 8      Anna Taylor
# 9       Liam Green
# Name: Name, dtype: object

# %%
#Convert a Dictionary to a DataFrame
import pandas as pd
data={
    "Product":["Roti","Kapda","Makaan"],
      "Price":[10,1000,1000000],
    "Quantity":[1000,10,1]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Product    Price  Quantity
# 0    Roti       10      1000
# 1   Kapda     1000        10
# 2  Makaan  1000000         1

# %%
#Convert a Series to a DataFrame
import pandas as pd
df = pd.read_csv("pandas_forms_data.csv")
Employee_Name = pd.Series.to_frame(pandas_series)
Employee_Name
# Out:
#             Name
# 0       John Doe
# 1     Jane Smith
# 2    Emily Davis
# 3  Michael Brown
# 4   Chris Wilson
# 5  Sarah Johnson
# 6      David Lee
# 7   Robert White
# 8    Anna Taylor
# 9     Liam Green

# %%
#Extract Multiple Columns as a DataFrame
import pandas as pd
df = pd.read_csv("pandas_forms_data.csv")
df[["Name","Age","Department"]]
# Out:
#             Name  Age Department
# 0       John Doe   28         IT
# 1     Jane Smith   32         HR
# 2    Emily Davis   45    Finance
# 3  Michael Brown   29         IT
# 4   Chris Wilson   35  Marketing
# 5  Sarah Johnson   40         HR
# 6      David Lee   50    Finance
# 7   Robert White   27  Marketing
# 8    Anna Taylor   30         IT
# 9     Liam Green   29    Finance

# %%
#Find Summary Statistics for Numeric Columns
import pandas as pd
df = pd.read_csv("pandas_forms_data.csv")
df.describe()
# Out:
#        Employee_ID        Age        Salary
# count     10.00000  10.000000     10.000000
# mean     105.50000  34.500000  64400.000000
# std        3.02765   7.933753  14569.374272
# min      101.00000  27.000000  49000.000000
# 25%      103.25000  29.000000  54250.000000
# 50%      105.50000  31.000000  61000.000000
# 75%      107.75000  38.750000  70750.000000
# max      110.00000  50.000000  95000.000000

# %%
#Set **"Employee_ID"** as the **index** of the DataFrame.
import pandas as pd
df = pd.read_csv("pandas_forms_data.csv")
df.index=df['Employee_ID']
df
# Out:
#              Employee_ID           Name  Age Department  Salary Joining_Date  \
# Employee_ID
# 101                  101       John Doe   28         IT   50000   2018-06-15
# 102                  102     Jane Smith   32         HR   60000   2016-09-23
# 103                  103    Emily Davis   45    Finance   80000   2012-11-04
# 104                  104  Michael Brown   29         IT   55000   2019-07-12
# 105                  105   Chris Wilson   35  Marketing   62000   2015-03-19
# 106                  106  Sarah Johnson   40         HR   72000   2014-05-28
# 107                  107      David Lee   50    Finance   95000   2010-12-17
# 108                  108   Robert White   27  Marketing   49000   2020-08-01
# 109                  109    Anna Taylor   30         IT   54000   2019-11-12
# 110                  110     Liam Green   29    Finance   67000   2011-02-14
#
#                       City
# Employee_ID
# 101               New York
# 102            Los Angeles
# ...

# %%
#Convert DataFrame Back to a Dictionary
import pandas as pd
df = pd.read_csv("pandas_forms_data.csv")
data=pd.DataFrame.to_dict(df)
data
# Out:
# {'Employee_ID': {0: 101,
#   1: 102,
#   2: 103,
#   3: 104,
#   4: 105,
#   5: 106,
#   6: 107,
#   7: 108,
#   8: 109,
#   9: 110},
#  'Name': {0: 'John Doe',
#   1: 'Jane Smith',
#   2: 'Emily Davis',
#   3: 'Michael Brown',
#   4: 'Chris Wilson',
#   5: 'Sarah Johnson',
#   6: 'David Lee',
#   7: 'Robert White',
#   8: 'Anna Taylor',
#   9: 'Liam Green'},
#  'Age': {0: 28, 1: 32, 2: 45, 3: 29, 4: 35, 5: 40, 6: 50, 7: 27, 8: 30, 9: 29},
#  'Department': {0: 'IT',
#   1: 'HR',
#   2: 'Finance',
#   3: 'IT',
#   4: 'Marketing',
#   5: 'HR',
#   6: 'Finance',
#   7: 'Marketing',
#   8: 'IT',
#   9: 'Finance'},
#  'Salary': {0: 50000,
#   1: 60000,
#   2: 80000,
#   3: 55000,
#   4: 62000,
#   5: 72000,
#   6: 95000,
#   7: 49000,
#   8: 54000,
#   9: 67000},
#  'Joining_Date': {0: '2018-06-15',
#   1: '2016-09-23',
#   2: '2012-11-04',
#   3: '2019-07-12',
#   4: '2015-03-19',
#   5: '2014-05-28',
#   6: '2010-12-17',
#   7: '2020-08-01',
#   8: '2019-11-12',
#   9: '2011-02-14'},
# ...

# %%
#
import pandas as pd
df = pd.read_csv("pandas_forms_data.csv")
df.rename(columns={"Salary":"Annual_salary"}, inplace=True)
df.rename(columns={"City":"Location"}, inplace=True)
df
# Out:
#    Employee_ID           Name  Age Department  Annual_salary Joining_Date  \
# 0          101       John Doe   28         IT          50000   2018-06-15
# 1          102     Jane Smith   32         HR          60000   2016-09-23
# 2          103    Emily Davis   45    Finance          80000   2012-11-04
# 3          104  Michael Brown   29         IT          55000   2019-07-12
# 4          105   Chris Wilson   35  Marketing          62000   2015-03-19
# 5          106  Sarah Johnson   40         HR          72000   2014-05-28
# 6          107      David Lee   50    Finance          95000   2010-12-17
# 7          108   Robert White   27  Marketing          49000   2020-08-01
# 8          109    Anna Taylor   30         IT          54000   2019-11-12
# 9          110     Liam Green   29    Finance          67000   2011-02-14
#
#         Location
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3       New York
# 4  San Francisco
# 5    Los Angeles
# 6        Chicago
# ...

# %%
#Save the Updated Data to a New CSV File
import pandas as pd
df = pd.read_csv("pandas_forms_data.csv")
df.index=df['Employee_ID']
df.rename(columns={"Salary":"Annual_salary"}, inplace=True)
df.rename(columns={"City":"Location"}, inplace=True)
df.to_csv("updated_pandas_forms_data.csv")
df
# Out:
#              Employee_ID           Name  Age Department  Annual_salary  \
# Employee_ID
# 101                  101       John Doe   28         IT          50000
# 102                  102     Jane Smith   32         HR          60000
# 103                  103    Emily Davis   45    Finance          80000
# 104                  104  Michael Brown   29         IT          55000
# 105                  105   Chris Wilson   35  Marketing          62000
# 106                  106  Sarah Johnson   40         HR          72000
# 107                  107      David Lee   50    Finance          95000
# 108                  108   Robert White   27  Marketing          49000
# 109                  109    Anna Taylor   30         IT          54000
# 110                  110     Liam Green   29    Finance          67000
#
#             Joining_Date       Location
# Employee_ID
# 101           2018-06-15       New York
# 102           2016-09-23    Los Angeles
# ...
